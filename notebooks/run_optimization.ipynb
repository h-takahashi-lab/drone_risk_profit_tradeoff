# %%
# ライブラリのインポート
import osmnx as ox
import pandas as pd
import geopandas as gpd
import networkx as nx
import os
import zipfile
import matplotlib.pyplot as plt
import japanize_matplotlib 
from matplotlib.ticker import MaxNLocator
from tqdm.auto import tqdm
from shapely.geometry import LineString, Point
import datetime as dt
from pathlib import Path
import pydeck as pdk
import numpy as np
import math
from geopy.distance import geodesic
import scipy
from shapely.wkt import loads

import gurobipy as gp
from gurobipy import Model, GRB
import logging
from itertools import product
import time

# %% [markdown]
# # データのインポート

# %%
PROJECT_ROOT = "../"
INTERMEDIATE_OUTPUT_DIR = PROJECT_ROOT + 'output/' + 'intermediate_data/'
# 入力ファイルパス
OPTIMIZATION_VARS_NPZ = INTERMEDIATE_OUTPUT_DIR + 'optimization_vars.npz'
FACILITY_NODE_PKL = INTERMEDIATE_OUTPUT_DIR + 'facility.pkl'
DESTINATION_NODE_PKL = INTERMEDIATE_OUTPUT_DIR + 'destination.pkl'

# %%
def load_data(vars_path: Path) -> dict:
    """最適化に必要な変数を.npzファイルから読み込む。"""
    logging.info(f"Loading optimization variables from {vars_path}...")
    try:
        # allow_pickle=True は、Numpy配列以外のオブジェクト（辞書など）を読み込むために必要
        data = np.load(vars_path, allow_pickle=True)
        # .item() を使って辞書オブジェクトを取り出す
        return {key: data[key].item() if data[key].dtype == 'O' else data[key] for key in data.files}
    except FileNotFoundError:
        logging.error(f"Error: Input file not found at {vars_path}")
        logging.error("Please run '01_prepare_data.py' first.")
        exit()

# %%
# データの読み込み
params = load_data(OPTIMIZATION_VARS_NPZ)
facility_df = pd.read_pickle(FACILITY_NODE_PKL)
destination_df = pd.read_pickle(DESTINATION_NODE_PKL)

# %% [markdown]
# # 最適化

# %%
# --- 最適化モデルクラス ---
class DroneDepotOptimizer:
    """ドローン配送拠点最適化モデルを構築・実行するクラス。"""

    def __init__(self, params: dict):
        """
        クラスの初期化。最適化に必要なパラメータを格納する。
        Args:
            params (dict): 01_prepare_data.pyで作成された変数の辞書
        """
        self.params = params
        self.model = None
        self.vars = {}

    def build(self, weights: dict):
        """
        Gurobiモデルを構築する。
        Args:
            weights (dict): 目的関数の重み {'profit': float, 'risk': float}
        """
        self.model = gp.Model("DroneDepotPlacement")

        # --- 変数定義 ---
        n_facilities = len(self.params['NODE_F'])
        n_destinations = len(self.params['NODE_D'])

        self.vars['open_f'] = self.model.addMVar(
            shape=n_facilities, vtype=GRB.BINARY, name="open_f"
        )
        self.vars['cover_d'] = self.model.addMVar(
            shape=n_destinations, vtype=GRB.BINARY, name="cover_d"
        )
        self.vars['connected_f_d'] = self.model.addMVar(
            shape=(n_facilities, n_destinations), vtype=GRB.BINARY, name="connected_f_d"
        )

        # --- 制約条件 ---
        # 1. 開設される施設数はK個
        self.model.addConstr(
            self.vars['open_f'].sum() == self.params['NUM_OPEN_FACILITIES'],
            name="num_open_facilities"
        )
        
        # 2. 閉鎖された施設からは接続できない
        # M: 十分に大きな数（ここでは需要地点の総数）
        M = n_destinations
        self.model.addConstr(
            self.vars['connected_f_d'].sum(axis=1) <= self.vars['open_f'] * M,
            name="no_connection_from_closed"
        )

        # 3. 各需要地点は、最大1つの施設からカバーされる
        #   sum(x_ij for i) = y_j
        self.model.addConstr(
            self.vars['connected_f_d'].sum(axis=0) == self.vars['cover_d'],
            name="at_most_one_connection"
        )

        # 4. ドローンの航続距離制約
        #   d_ij * x_ij <= E
        self.model.addConstr(
            self.vars['connected_f_d'] * self.params['DISTANCE_F_D'] <= self.params.get('UAV_ENDURANCE', 3),
            name="endurance_limit"
        )

        # --- 目的関数 ---
        # 目的1: 総収益性
        total_profit = (self.params['PROFITABILITY_F_D'] * self.vars['connected_f_d']).sum()
        
        # 目的2: カバーされた期待被害者数
        covered_risk = self.vars['cover_d'] @ (self.params['RISK_D'] * self.params['POPULATION_D'])
        
        # 正規化のための基準値（理想点）を取得
        b_profit = weights.get('b_profit', 1.0)
        b_risk = weights.get('b_risk', 1.0)

        print(b_profit, b_risk)  # デバッグ用ログ出力
        
        # # ゼロ割を避ける
        # if b_profit == 0: b_profit = 1.0
        # if b_risk == 0: b_risk = 1.0
        
        # 正規化された目的関数
        objective = (weights['profit'] * (total_profit / b_profit) +
                     weights['risk'] * (covered_risk / b_risk)) 
        
        self.model.setObjective(objective, GRB.MAXIMIZE)

    def solve(self) -> dict:
        """モデルを解き、結果を返す。"""
        self.model.optimize()
        
        if self.model.Status == GRB.OPTIMAL:
            logging.info(f"Optimal solution found. Objective value: {self.model.ObjVal:.4f}")
            # 結果を抽出
            results = {
                'status': 'optimal',
                'obj_val': self.model.ObjVal,
                'open_f': self.vars['open_f'].X.astype(int),
                'cover_d': self.vars['cover_d'].X.astype(int),
                'connected_f_d': self.vars['connected_f_d'].X.astype(int),
                'total_profit': (self.params['PROFITABILITY_F_D'] * self.vars['connected_f_d'].X).sum(),
                'covered_risk': self.vars['cover_d'].X @ (self.params['RISK_D'] * self.params['POPULATION_D'])
            }
            return results
        else:
            logging.warning(f"Optimization finished with status code: {self.model.Status}")
            if self.model.Status == GRB.INFEASIBLE:
                logging.info("Model is infeasible. Computing IIS to find the cause...")
                self.model.computeIIS()
                self.model.write("infeasible_model.ilp")
                logging.info("IIS written to 'infeasible_model.ilp'")
            return {'status': 'failed'}

# %%
# --- メイン実行関数 ---
def run_single_scenario(params: dict):
    """最適化の全フローを実行する。"""
    optimizer = DroneDepotOptimizer(params)
    
    # --- 1. 基準値（理想点）の計算 ---
    logging.info("--- Step 1: Calculating benchmark values (Utopia Point) ---")
    
    # 収益性のみ最大化
    logging.info("Maximizing for PROFIT only...")
    optimizer.build(weights={'profit': 1.0, 'risk': 0.0})
    profit_only_results = optimizer.solve()
    b_profit = profit_only_results.get('total_profit', 1.0)

    # リスク削減のみ最大化
    logging.info("Maximizing for RISK REDUCTION only...")
    optimizer.build(weights={'profit': 0.0, 'risk': 1.0})
    risk_only_results = optimizer.solve()
    b_risk = risk_only_results.get('covered_risk', 1.0)

    logging.info(f"Benchmark values: B_PROFIT = {b_profit:,.0f}, B_RISK = {b_risk:,.2f}")

    # --- 2. 多目的最適化（重み付け法） ---
    logging.info("--- Step 2: Running multi-objective optimization with weighted-sum ---")
    
    # 探索する重みのリスト
    omega_list = [1.0, 0.99, 0.95, 0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1, 0.05, 0.01, 0.0]
    
    scenario_results = []

    for omega_profit in omega_list:
        omega_risk = round(1 - omega_profit, 2)
        logging.info(f"Solving for omega_profit={omega_profit:.2f}, omega_risk={omega_risk:.2f}...")
        
        weights = {
            'profit': omega_profit,
            'risk': omega_risk,
            'b_profit': b_profit,
            'b_risk': b_risk
        }
        
        optimizer.build(weights=weights)
        result = optimizer.solve()
        
        if result['status'] == 'optimal':
            result['omega_profit'] = omega_profit
            result['omega_risk'] = omega_risk
            scenario_results.append(result)

    return scenario_results

# %%
final_results = run_single_scenario(params)
# Out:
# 1.0 1.0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x8864249c
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [2e+03, 2e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 272096 columns
# Presolve time: 0.10s
# Presolved: 1031 rows, 8955 columns, 17901 nonzeros
# Variable types: 0 continuous, 8955 integer (8955 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.04s
#
# Root relaxation: objective 2.607846e+08, 8662 iterations, 0.12 seconds (0.21 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2.6078e+08    0  136   -0.00000 2.6078e+08      -     -    0s
# H    0     0                    1.235664e+08 2.6078e+08   111%     -    0s
# H    0     0                    1.296995e+08 2.6078e+08   101%     -    0s
# H    0     0                    1.330110e+08 2.6078e+08  96.1%     -    0s
# H    0     0                    2.208651e+08 2.6078e+08  18.1%     -    0s
# H    0     0                    2.209672e+08 2.6078e+08  18.0%     -    0s
# H    0     0                    2.213261e+08 2.6078e+08  17.8%     -    0s
# H    0     0                    2.605493e+08 2.6078e+08  0.09%     -    0s
#      0     0 2.6065e+08    0  134 2.6055e+08 2.6065e+08  0.04%     -    0s
# *    0     0               0    2.606439e+08 2.6064e+08 -0.00%     -    0s
#
# Explored 1 nodes (8886 simplex iterations) in 0.52 seconds (0.57 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 9: 2.60644e+08 2.60549e+08 2.21326e+08 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.606438667957e+08, best bound 2.606438667957e+08, gap 0.0000%
# 1.0 1.0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x2a31c764
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [2e-14, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280022 rows and 272118 columns
# Presolve time: 0.09s
# Presolved: 1030 rows, 8933 columns, 17715 nonzeros
# Variable types: 0 continuous, 8933 integer (8933 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 1.103331e+04, 7883 iterations, 0.08 seconds (0.15 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 11033.3140    0  218   -0.00000 11033.3140      -     -    0s
# H    0     0                    10515.507655 11033.3140  4.92%     -    0s
# H    0     0                    10887.320372 11033.3140  1.34%     -    0s
# H    0     0                    10967.010140 11033.3140  0.60%     -    0s
# H    0     0                    10991.760902 11033.3140  0.38%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Zero half: 1
#   RLT: 2
#
# Explored 1 nodes (11363 simplex iterations) in 0.45 seconds (0.54 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 10991.8 10967 10887.3 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.099176090217e+04, best bound 1.099176090217e+04, gap 0.0000%
# 260643866.79573792 10991.760902173073
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0xf6bd04a2
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [7e-06, 7e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 272096 columns
# Presolve time: 0.10s
# Presolved: 1031 rows, 8955 columns, 17901 nonzeros
# Variable types: 0 continuous, 8955 integer (8955 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.04s
#
# Root relaxation: objective 1.000540e+00, 8605 iterations, 0.13 seconds (0.22 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.00054    0  136   -0.00000    1.00054      -     -    0s
# H    0     0                       0.4740815    1.00054   111%     -    0s
# H    0     0                       0.4976119    1.00054   101%     -    0s
# H    0     0                       0.5103168    1.00054  96.1%     -    0s
# H    0     0                       0.8473827    1.00054  18.1%     -    0s
# H    0     0                       0.8477743    1.00054  18.0%     -    0s
# H    0     0                       0.8491515    1.00054  17.8%     -    0s
# H    0     0                       0.9996371    1.00054  0.09%     -    0s
#      0     0    1.00016    0  110    0.99964    1.00016  0.05%     -    0s
# *    0     0               0       1.0000000    1.00000  0.00%     -    0s
#
# Explored 1 nodes (8690 simplex iterations) in 0.49 seconds (0.56 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 9: 1 0.999637 0.849152 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# 260643866.79573792 10991.760902173073
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0xbddebbd9
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [2e-20, 7e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271959 columns
# Presolve time: 0.08s
# Presolved: 1031 rows, 9092 columns, 18038 nonzeros
# Variable types: 0 continuous, 9092 integer (9092 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.04s
#
# Root relaxation: objective 9.989662e-01, 8675 iterations, 0.13 seconds (0.24 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.99897    0  149   -0.00000    0.99897      -     -    0s
# H    0     0                       0.5073986    0.99897  96.9%     -    0s
# H    0     0                       0.5074228    0.99897  96.9%     -    0s
# H    0     0                       0.5116228    0.99897  95.3%     -    0s
# H    0     0                       0.8505621    0.99897  17.4%     -    0s
# H    0     0                       0.9449430    0.99897  5.72%     -    0s
# H    0     0                       0.9666909    0.99897  3.34%     -    0s
# H    0     0                       0.9777013    0.99897  2.17%     -    0s
# H    0     0                       0.9977587    0.99897  0.12%     -    0s
# H    0     0                       0.9978378    0.99897  0.11%     -    0s
# H    0     0                       0.9986686    0.99897  0.03%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Zero half: 1
#   RLT: 21
#
# Explored 1 nodes (8676 simplex iterations) in 0.43 seconds (0.54 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 0.998669 0.997838 0.997759 ... 0.507399
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.986685982528e-01, best bound 9.986685982559e-01, gap 0.0000%
# 260643866.79573792 10991.760902173073
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0xdf6d8482
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [8e-20, 7e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271958 columns
# Presolve time: 0.08s
# Presolved: 1031 rows, 9093 columns, 18039 nonzeros
# Found heuristic solution: objective 0.0000000
# Variable types: 0 continuous, 9093 integer (9093 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.05s
#
# Root relaxation: objective 9.950810e-01, 8713 iterations, 0.13 seconds (0.24 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9950810    0.99508  0.00%     -    0s
#
# Explored 1 nodes (8713 simplex iterations) in 0.37 seconds (0.48 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 0.995081 1.51429e-10
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.950810294005e-01, best bound 9.950810294163e-01, gap 0.0000%
# 260643866.79573792 10991.760902173073
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0xb84c878d
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [2e-19, 6e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271957 columns
# Presolve time: 0.08s
# Presolved: 1031 rows, 9094 columns, 18040 nonzeros
# Found heuristic solution: objective 0.0000000
# Variable types: 0 continuous, 9094 integer (9094 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.04s
#
# Root relaxation: objective 9.914754e-01, 8625 iterations, 0.13 seconds (0.24 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9914754    0.99148  0.00%     -    0s
#
# Explored 1 nodes (8625 simplex iterations) in 0.33 seconds (0.49 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 0.991475 1.24952e-10
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.914754465898e-01, best bound 9.914754466213e-01, gap 0.0000%
# 260643866.79573792 10991.760902173073
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x57df0494
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [3e-19, 6e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271956 columns
# Presolve time: 0.09s
# Presolved: 1031 rows, 9095 columns, 18041 nonzeros
# Variable types: 0 continuous, 9095 integer (9095 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.04s
#
# Root relaxation: objective 9.844226e-01, 8471 iterations, 0.13 seconds (0.23 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9844226    0.98442  0.00%     -    0s
#
# Explored 1 nodes (8471 simplex iterations) in 0.33 seconds (0.47 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 0.984423 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.844225669799e-01, best bound 9.844225670429e-01, gap 0.0000%
# 260643866.79573792 10991.760902173073
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x4c384265
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [5e-19, 5e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271956 columns
# Presolve time: 0.08s
# Presolved: 1031 rows, 9095 columns, 18041 nonzeros
# Variable types: 0 continuous, 9095 integer (9095 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 9.800996e-01, 8619 iterations, 0.14 seconds (0.27 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9800996    0.98010  0.00%     -    0s
#
# Explored 1 nodes (8619 simplex iterations) in 0.33 seconds (0.51 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 0.9801 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.800995590758e-01, best bound 9.800995591704e-01, gap 0.0000%
# 260643866.79573792 10991.760902173073
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x2ec19eea
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [6e-19, 5e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271955 columns
# Presolve time: 0.08s
# Presolved: 1031 rows, 9096 columns, 18042 nonzeros
# Variable types: 0 continuous, 9096 integer (9096 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 9.762447e-01, 8690 iterations, 0.13 seconds (0.26 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9762447    0.97624  0.00%     -    0s
#
# Explored 1 nodes (8690 simplex iterations) in 0.33 seconds (0.50 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 0.976245 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.762447353657e-01, best bound 9.762447353702e-01, gap 0.0000%
# 260643866.79573792 10991.760902173073
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x1d8b7c3f
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [8e-19, 6e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271955 columns
# Presolve time: 0.08s
# Presolved: 1031 rows, 9096 columns, 18042 nonzeros
# Variable types: 0 continuous, 9096 integer (9096 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 9.723899e-01, 8614 iterations, 0.13 seconds (0.25 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9723899    0.97239  0.00%     -    0s
#
# Explored 1 nodes (8614 simplex iterations) in 0.33 seconds (0.50 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 0.97239 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.723899116556e-01, best bound 9.723899116612e-01, gap 0.0000%
# 260643866.79573792 10991.760902173073
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x55ab4edc
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [9e-19, 7e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271955 columns
# Presolve time: 0.08s
# Presolved: 1031 rows, 9096 columns, 18042 nonzeros
# Variable types: 0 continuous, 9096 integer (9096 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.04s
#
# Root relaxation: objective 9.702011e-01, 8647 iterations, 0.13 seconds (0.25 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.97020    0  219   -0.00000    0.97020      -     -    0s
# H    0     0                       0.8856115    0.97020  9.55%     -    0s
# H    0     0                       0.8908227    0.97020  8.91%     -    0s
# H    0     0                       0.9297368    0.97020  4.35%     -    0s
# H    0     0                       0.9297760    0.97020  4.35%     -    0s
# H    0     0                       0.9685351    0.97020  0.17%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Zero half: 3
#
# Explored 1 nodes (8647 simplex iterations) in 0.61 seconds (0.62 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 6: 0.968535 0.929776 0.929737 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.685350879455e-01, best bound 9.685350879522e-01, gap 0.0000%
# 260643866.79573792 10991.760902173073
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0xc80fe3e1
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [1e-18, 8e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271955 columns
# Presolve time: 0.08s
# Presolved: 1031 rows, 9096 columns, 18042 nonzeros
# Variable types: 0 continuous, 9096 integer (9096 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 9.699584e-01, 8473 iterations, 0.12 seconds (0.23 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.96996    0  288   -0.00000    0.96996      -     -    0s
# H    0     0                       0.9238643    0.96996  4.99%     -    0s
# H    0     0                       0.9507231    0.96996  2.02%     -    0s
# H    0     0                       0.9512044    0.96996  1.97%     -    0s
# H    0     0                       0.9663998    0.96996  0.37%     -    0s
#      0     0    0.96942    0  308    0.96640    0.96942  0.31%     -    0s
#      0     0    0.96815    0   97    0.96640    0.96815  0.18%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Zero half: 1
#   RLT: 1
#
# Explored 1 nodes (9094 simplex iterations) in 0.59 seconds (0.68 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 0.9664 0.951204 0.950723 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.663998233472e-01, best bound 9.663998233551e-01, gap 0.0000%
# 260643866.79573792 10991.760902173073
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x6b9821a2
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [1e-18, 9e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271955 columns
# Presolve time: 0.08s
# Presolved: 1031 rows, 9096 columns, 18042 nonzeros
# Variable types: 0 continuous, 9096 integer (9096 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.04s
#
# Root relaxation: objective 9.731387e-01, 8358 iterations, 0.11 seconds (0.20 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.97314    0  288   -0.00000    0.97314      -     -    0s
# H    0     0                       0.8885350    0.97314  9.52%     -    0s
# H    0     0                       0.9542272    0.97314  1.98%     -    0s
# H    0     0                       0.9545481    0.97314  1.95%     -    0s
# H    0     0                       0.9567934    0.97314  1.71%     -    0s
# H    0     0                       0.9694133    0.97314  0.38%     -    0s
#      0     0    0.97236    0  304    0.96941    0.97236  0.30%     -    0s
#      0     0    0.97236    0  104    0.96941    0.97236  0.30%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Zero half: 26
#
# Explored 1 nodes (9025 simplex iterations) in 0.60 seconds (0.67 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 6: 0.969413 0.956793 0.954548 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.694132858536e-01, best bound 9.694132858626e-01, gap 0.0000%
# 260643866.79573792 10991.760902173073
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x83ea9dce
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [1e-18, 1e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271955 columns
# Presolve time: 0.08s
# Presolved: 1031 rows, 9096 columns, 18042 nonzeros
# Variable types: 0 continuous, 9096 integer (9096 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 9.780761e-01, 8361 iterations, 0.09 seconds (0.18 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.97808    0  332   -0.00000    0.97808      -     -    0s
# H    0     0                       0.9333142    0.97808  4.80%     -    0s
# H    0     0                       0.9361213    0.97808  4.48%     -    0s
# H    0     0                       0.9361366    0.97808  4.48%     -    0s
# H    0     0                       0.9361450    0.97808  4.48%     -    0s
# H    0     0                       0.9709253    0.97808  0.74%     -    0s
# H    0     0                       0.9724267    0.97808  0.58%     -    0s
# H    0     0                       0.9763510    0.97808  0.18%     -    0s
#
# Cutting planes:
#   Zero half: 1
#
# Explored 1 nodes (8362 simplex iterations) in 0.47 seconds (0.56 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 8: 0.976351 0.972427 0.970925 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.763510351610e-01, best bound 9.763510351711e-01, gap 0.0000%
# 260643866.79573792 10991.760902173073
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0xa12dd9ca
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [1e-18, 1e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271955 columns
# Presolve time: 0.08s
# Presolved: 1031 rows, 9096 columns, 18042 nonzeros
# Variable types: 0 continuous, 9096 integer (9096 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.04s
#
# Root relaxation: objective 9.856743e-01, 9332 iterations, 0.10 seconds (0.17 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.98567    0   37   -0.00000    0.98567      -     -    0s
# H    0     0                       0.9489834    0.98567  3.87%     -    0s
# H    0     0                       0.9753329    0.98567  1.06%     -    0s
# H    0     0                       0.9787234    0.98567  0.71%     -    0s
# H    0     0                       0.9836363    0.98567  0.21%     -    0s
# H    0     0                       0.9836372    0.98567  0.21%     -    0s
#
# Cutting planes:
#   RLT: 1
#
# Explored 1 nodes (9332 simplex iterations) in 0.37 seconds (0.46 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 6: 0.983637 0.983636 0.978723 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.836371767855e-01, best bound 9.836371767962e-01, gap 0.0000%
# 260643866.79573792 10991.760902173073
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x64078577
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [2e-18, 1e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271955 columns
# Presolve time: 0.08s
# Presolved: 1031 rows, 9096 columns, 18042 nonzeros
# Variable types: 0 continuous, 9096 integer (9096 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 9.991782e-01, 9353 iterations, 0.12 seconds (0.19 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.99918    0  220   -0.00000    0.99918      -     -    0s
# H    0     0                       0.9549358    0.99918  4.63%     -    0s
# H    0     0                       0.9677656    0.99918  3.25%     -    0s
# H    0     0                       0.9953207    0.99918  0.39%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Zero half: 2
#
# Explored 1 nodes (9361 simplex iterations) in 0.54 seconds (0.52 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 0.995321 0.967766 0.954936 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.953207290614e-01, best bound 9.953207290726e-01, gap 0.0000%
# 260643866.79573792 10991.760902173073
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0xc981400a
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [2e-18, 1e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280023 rows and 272144 columns
# Presolve time: 0.08s
# Presolved: 1029 rows, 8907 columns, 17664 nonzeros
# Variable types: 0 continuous, 8907 integer (8907 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 1.003780e+00, 7271 iterations, 0.07 seconds (0.13 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.00378    0  212   -0.00000    1.00378      -     -    0s
# H    0     0                       0.9566714    1.00378  4.92%     -    0s
# H    0     0                       0.9725116    1.00378  3.22%     -    0s
# H    0     0                       0.9977478    1.00378  0.60%     -    0s
# H    0     0                       0.9999996    1.00378  0.38%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Zero half: 1
#
# Explored 1 nodes (10425 simplex iterations) in 0.42 seconds (0.50 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 1 0.997748 0.972512 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.999995813555e-01, best bound 9.999995813668e-01, gap 0.0000%

# %% [markdown]
# # 結果の保存

# %%
FINAL_OUTPUT_DIR = PROJECT_ROOT + 'output/' + 'final_results/'
OPTIMIZATION_RESULTS_PKL = FINAL_OUTPUT_DIR + 'optimization_results.pkl'
OPTIMIZATION_PARAMS_PKL = FINAL_OUTPUT_DIR + 'optimization_params.npz'

# %%
def save_results(results: list, params: dict, facility_df: pd.DataFrame, destination_df: pd.DataFrame, result_path: str,params_path:str):
    """最適化結果を整形し、ファイルに保存する。"""
    logging.info(f"--- Step 3: Saving results and parameters to {result_path} and {params_path}---")
    
    if not results:
        logging.warning("No optimal results to save.")
        return

    # 結果をDataFrameに変換
    results_df = pd.DataFrame(results)
    
    # 未カバーのリスク（最小化したい対象）を計算
    max_risk = params['MAX_SUM_UNCOVERED_ISOLATED_PEOPLE']
    results_df['uncovered_risk'] = max_risk - results_df['covered_risk']

    # 保存用データ構造
    output_data = {
        'summary': results_df,
        'params': params,
        'facility_nodes': facility_df,
        'destination_nodes': destination_df
    }
    
    
    # 保存
    results_df.to_pickle(result_path)
    np.savez(params_path, **params)
    logging.info(f"Successfully saved optimization results to {result_path} and parameters to {params_path}")

# %%
save_results(final_results, params, facility_df, destination_df, OPTIMIZATION_RESULTS_PKL,OPTIMIZATION_PARAMS_PKL)

# %% [markdown]
# # Sensitivity Analysis

# %%
import time

# %%
# ## 感度分析のメインフロー
start_time = time.time()
base_params = params.copy()
all_results_collection = {}

# %%
# --- 分析1: 施設数 N_f の感度分析 ---
logging.info("--- Starting Sensitivity Analysis for Number of Facilities (N_f) ---")
n_f_list = [6, 8, 10, 12, 14, 16, 18, 20]
n_f_results = []
for n_f in tqdm(n_f_list, desc="N_f Analysis"):
    logging.info(f"--- Running for N_f = {n_f} ---")
    current_params = base_params.copy()
    current_params['NUM_OPEN_FACILITIES'] = n_f
    
    results_for_nf = run_single_scenario(current_params)
    for res in results_for_nf:
        res['n_f'] = n_f
    n_f_results.extend(results_for_nf)
    
all_results_collection['n_f_analysis'] = pd.DataFrame(n_f_results)
logging.info("--- Finished N_f analysis ---")
# Out:
# N_f Analysis:   0%|          | 0/8 [00:00<?, ?it/s]
# 1.0 1.0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x784718ca
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [2e+03, 2e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 272096 columns
# Presolve time: 0.09s
# Presolved: 1031 rows, 8955 columns, 17901 nonzeros
# Variable types: 0 continuous, 8955 integer (8955 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 2.148076e+08, 8155 iterations, 0.08 seconds (0.16 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2.1481e+08    0  165   -0.00000 2.1481e+08      -     -    0s
# H    0     0                    7.783353e+07 2.1481e+08   176%     -    0s
# H    0     0                    1.306117e+08 2.1481e+08  64.5%     -    0s
# H    0     0                    1.363710e+08 2.1481e+08  57.5%     -    0s
# H    0     0                    1.751102e+08 2.1481e+08  22.7%     -    0s
# H    0     0                    2.136183e+08 2.1481e+08  0.56%     -    0s
# H    0     0                    2.143466e+08 2.1481e+08  0.22%     -    0s
# H    0     0                    2.145055e+08 2.1481e+08  0.14%     -    0s
#
# Cutting planes:
#   Zero half: 4
#
# Explored 1 nodes (8155 simplex iterations) in 0.44 seconds (0.49 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 8: 2.14506e+08 2.14347e+08 2.13618e+08 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.145055074150e+08, best bound 2.145094007461e+08, gap 0.0018%
# 1.0 1.0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x7848138f
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [2e-14, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280022 rows and 272118 columns
# Presolve time: 0.09s
# Presolved: 1030 rows, 8933 columns, 17715 nonzeros
# Variable types: 0 continuous, 8933 integer (8933 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.04s
#
# Root relaxation: objective 8.256122e+03, 7807 iterations, 0.05 seconds (0.11 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    8256.1222312 8256.12223  0.00%     -    0s
#
# Explored 1 nodes (7807 simplex iterations) in 0.27 seconds (0.35 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 8256.12 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.256122231173e+03, best bound 8.256122231173e+03, gap 0.0000%
# 214505507.4150368 8256.122231172674
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0xcd2c5176
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [8e-06, 8e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 272096 columns
# Presolve time: 0.08s
# Presolved: 1031 rows, 8955 columns, 17901 nonzeros
# Variable types: 0 continuous, 8955 integer (8955 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 1.001408e+00, 8178 iterations, 0.08 seconds (0.16 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.00141    0  165   -0.00000    1.00141      -     -    0s
# H    0     0                       0.3628510    1.00141   176%     -    0s
# H    0     0                       0.6088969    1.00141  64.5%     -    0s
# H    0     0                       0.6357460    1.00141  57.5%     -    0s
# H    0     0                       0.8163435    1.00141  22.7%     -    0s
# H    0     0                       0.9958642    1.00141  0.56%     -    0s
# H    0     0                       1.0000000    1.00141  0.14%     -    0s
#
# Cutting planes:
#   Zero half: 4
#
# Explored 1 nodes (8178 simplex iterations) in 0.42 seconds (0.50 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 7: 1 0.995864 0.816343 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# 214505507.4150368 8256.122231172674
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x4a08cb48
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [2e-20, 8e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271959 columns
# Presolve time: 0.08s
# Presolved: 1031 rows, 9092 columns, 18038 nonzeros
# Found heuristic solution: objective 0.0000000
# Variable types: 0 continuous, 9092 integer (9092 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 9.993000e-01, 8033 iterations, 0.08 seconds (0.16 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.99930    0  192    0.00000    0.99930      -     -    0s
# H    0     0                       0.5396876    0.99930  85.2%     -    0s
# H    0     0                       0.6023750    0.99930  65.9%     -    0s
# H    0     0                       0.9024796    0.99930  10.7%     -    0s
# H    0     0                       0.9073268    0.99930  10.1%     -    0s
# H    0     0                       0.9093708    0.99930  9.89%     -    0s
# H    0     0                       0.9932511    0.99930  0.61%     -    0s
# H    0     0                       0.9989053    0.99930  0.04%     -    0s
#
# Cutting planes:
#   Zero half: 5
#
# Explored 1 nodes (8033 simplex iterations) in 0.43 seconds (0.49 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 8: 0.998905 0.993251 0.909371 ... 1.23374e-10
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.989053160412e-01, best bound 9.989053160454e-01, gap 0.0000%
# 214505507.4150368 8256.122231172674
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x349157e0
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [1e-19, 8e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271957 columns
# Presolve time: 0.08s
# Presolved: 1031 rows, 9094 columns, 18040 nonzeros
# Variable types: 0 continuous, 9094 integer (9094 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 9.945266e-01, 7943 iterations, 0.07 seconds (0.14 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9945266    0.99453  0.00%     -    0s
#
# Explored 1 nodes (7943 simplex iterations) in 0.27 seconds (0.39 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 0.994527 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.945265802061e-01, best bound 9.945265802271e-01, gap 0.0000%
# 214505507.4150368 8256.122231172674
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x7404578a
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [2e-19, 8e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271956 columns
# Presolve time: 0.09s
# Presolved: 1031 rows, 9095 columns, 18041 nonzeros
# Variable types: 0 continuous, 9095 integer (9095 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 9.890532e-01, 8001 iterations, 0.07 seconds (0.15 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9890532    0.98905  0.00%     -    0s
#
# Explored 1 nodes (8001 simplex iterations) in 0.28 seconds (0.39 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 0.989053 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.890531604123e-01, best bound 9.890531604542e-01, gap 0.0000%
# 214505507.4150368 8256.122231172674
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x063aa32e
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [4e-19, 7e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271956 columns
# Presolve time: 0.08s
# Presolved: 1031 rows, 9095 columns, 18041 nonzeros
# Variable types: 0 continuous, 9095 integer (9095 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 9.819239e-01, 7938 iterations, 0.07 seconds (0.13 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9819239    0.98192  0.00%     -    0s
#
# Explored 1 nodes (7938 simplex iterations) in 0.29 seconds (0.38 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 0.981924 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.819239142582e-01, best bound 9.819239143422e-01, gap 0.0000%
# 214505507.4150368 8256.122231172674
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0xe078ae2c
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [6e-19, 6e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271955 columns
# Presolve time: 0.09s
# Presolved: 1031 rows, 9096 columns, 18042 nonzeros
# Variable types: 0 continuous, 9096 integer (9096 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 9.757650e-01, 7927 iterations, 0.07 seconds (0.15 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9757650    0.97576  0.00%     -    0s
#
# Explored 1 nodes (7927 simplex iterations) in 0.28 seconds (0.40 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 0.975765 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.757649921621e-01, best bound 9.757649921666e-01, gap 0.0000%
# 214505507.4150368 8256.122231172674
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x52315766
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [8e-19, 6e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271955 columns
# Presolve time: 0.09s
# Presolved: 1031 rows, 9096 columns, 18042 nonzeros
# Variable types: 0 continuous, 9096 integer (9096 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 9.696061e-01, 7862 iterations, 0.06 seconds (0.13 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9696061    0.96961  0.00%     -    0s
#
# Explored 1 nodes (7862 simplex iterations) in 0.28 seconds (0.38 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 0.969606 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.696060700660e-01, best bound 9.696060700720e-01, gap 0.0000%
# 214505507.4150368 8256.122231172674
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0xe9ee1363
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [1e-18, 8e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271955 columns
# Presolve time: 0.08s
# Presolved: 1031 rows, 9096 columns, 18042 nonzeros
# Variable types: 0 continuous, 9096 integer (9096 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 9.634471e-01, 7863 iterations, 0.06 seconds (0.13 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9634471    0.96345  0.00%     -    0s
#
# Explored 1 nodes (7863 simplex iterations) in 0.26 seconds (0.37 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 0.963447 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.634471479699e-01, best bound 9.634471479774e-01, gap 0.0000%
# 214505507.4150368 8256.122231172674
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x0bd6929c
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [1e-18, 9e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271955 columns
# Presolve time: 0.09s
# Presolved: 1031 rows, 9096 columns, 18042 nonzeros
# Variable types: 0 continuous, 9096 integer (9096 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 9.634007e-01, 7791 iterations, 0.06 seconds (0.12 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9634007    0.96340  0.00%     -    0s
#
# Explored 1 nodes (7791 simplex iterations) in 0.27 seconds (0.36 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 0.963401 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.634007339639e-01, best bound 9.634007339728e-01, gap 0.0000%
# 214505507.4150368 8256.122231172674
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0xddc52321
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [1e-18, 1e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271955 columns
# Presolve time: 0.08s
# Presolved: 1031 rows, 9096 columns, 18042 nonzeros
# Variable types: 0 continuous, 9096 integer (9096 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 9.654842e-01, 7817 iterations, 0.06 seconds (0.11 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9654842    0.96548  0.00%     -    0s
#
# Explored 1 nodes (7817 simplex iterations) in 0.26 seconds (0.35 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 0.965484 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.654841960998e-01, best bound 9.654841961103e-01, gap 0.0000%
# 214505507.4150368 8256.122231172674
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x118f241c
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [2e-18, 1e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271955 columns
# Presolve time: 0.09s
# Presolved: 1031 rows, 9096 columns, 18042 nonzeros
# Variable types: 0 continuous, 9096 integer (9096 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 9.675677e-01, 7797 iterations, 0.06 seconds (0.11 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9675677    0.96757  0.00%     -    0s
#
# Explored 1 nodes (7797 simplex iterations) in 0.27 seconds (0.36 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 0.967568 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.675676582357e-01, best bound 9.675676582477e-01, gap 0.0000%
# 214505507.4150368 8256.122231172674
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x21f3918d
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [2e-18, 1e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271955 columns
# Presolve time: 0.08s
# Presolved: 1031 rows, 9096 columns, 18042 nonzeros
# Variable types: 0 continuous, 9096 integer (9096 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 9.696511e-01, 7855 iterations, 0.06 seconds (0.11 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9696511    0.96965  0.00%     -    0s
#
# Explored 1 nodes (7855 simplex iterations) in 0.26 seconds (0.36 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 0.969651 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.696511203717e-01, best bound 9.696511203852e-01, gap 0.0000%
# 214505507.4150368 8256.122231172674
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x2e0c0507
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [2e-18, 1e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271955 columns
# Presolve time: 0.09s
# Presolved: 1031 rows, 9096 columns, 18042 nonzeros
# Variable types: 0 continuous, 9096 integer (9096 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 9.763866e-01, 7965 iterations, 0.06 seconds (0.12 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.97639    0  178   -0.00000    0.97639      -     -    0s
# H    0     0                       0.7713913    0.97639  26.6%     -    0s
# H    0     0                       0.7900074    0.97639  23.6%     -    0s
# H    0     0                       0.7900805    0.97639  23.6%     -    0s
# H    0     0                       0.8851471    0.97639  10.3%     -    0s
# H    0     0                       0.9756291    0.97639  0.08%     -    0s
# H    0     0                       0.9760174    0.97639  0.04%     -    0s
#
# Explored 1 nodes (7965 simplex iterations) in 0.36 seconds (0.41 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 7: 0.976017 0.975629 0.885147 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.760174387710e-01, best bound 9.760174387852e-01, gap 0.0000%
# 214505507.4150368 8256.122231172674
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x331ad298
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [2e-18, 2e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271955 columns
# Presolve time: 0.09s
# Presolved: 1031 rows, 9096 columns, 18042 nonzeros
# Variable types: 0 continuous, 9096 integer (9096 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 9.949662e-01, 7889 iterations, 0.06 seconds (0.11 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.99497    0  104   -0.00000    0.99497      -     -    0s
# H    0     0                       0.6583705    0.99497  51.1%     -    0s
# H    0     0                       0.6963618    0.99497  42.9%     -    0s
# H    0     0                       0.8156360    0.99497  22.0%     -    0s
# H    0     0                       0.8305926    0.99497  19.8%     -    0s
# H    0     0                       0.9949640    0.99497  0.00%     -    0s
#
# Explored 1 nodes (7889 simplex iterations) in 0.29 seconds (0.37 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 6: 0.994964 0.830593 0.815636 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.949639739054e-01, best bound 9.949662440141e-01, gap 0.0002%
# 214505507.4150368 8256.122231172674
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x0b8d4498
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [2e-18, 2e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 6e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280023 rows and 272144 columns
# Presolve time: 0.08s
# Presolved: 1029 rows, 8907 columns, 17664 nonzeros
# Variable types: 0 continuous, 8907 integer (8907 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 9.999994e-01, 7166 iterations, 0.05 seconds (0.09 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9999994    1.00000  0.00%     -    0s
#
# Explored 1 nodes (7166 simplex iterations) in 0.25 seconds (0.34 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 0.999999 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.999994426391e-01, best bound 9.999994426541e-01, gap 0.0000%
# N_f Analysis:  12%|█▎        | 1/8 [01:04<07:34, 64.94s/it]
# 1.0 1.0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x15112d43
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [2e+03, 2e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 8e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 272096 columns
# Presolve time: 0.11s
# Presolved: 1031 rows, 8955 columns, 17901 nonzeros
# Variable types: 0 continuous, 8955 integer (8955 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.04s
#
# Root relaxation: objective 2.349327e+08, 8938 iterations, 0.14 seconds (0.25 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2.3493e+08    0  206   -0.00000 2.3493e+08      -     -    0s
# H    0     0                    2.086365e+08 2.3493e+08  12.6%     -    0s
# H    0     0                    2.173631e+08 2.3493e+08  8.08%     -    0s
# H    0     0                    2.264905e+08 2.3493e+08  3.73%     -    0s
# H    0     0                    2.340920e+08 2.3493e+08  0.36%     -    0s
# H    0     0                    2.343392e+08 2.3493e+08  0.25%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Zero half: 4
#
# Explored 1 nodes (8938 simplex iterations) in 0.55 seconds (0.61 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 6: 2.34339e+08 2.34092e+08 2.2649e+08 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.343391637484e+08, best bound 2.343391637484e+08, gap 0.0000%
# 1.0 1.0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x9f7801cb
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [2e-14, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 8e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280022 rows and 272118 columns
# Presolve time: 0.08s
# Presolved: 1030 rows, 8933 columns, 17715 nonzeros
# Variable types: 0 continuous, 8933 integer (8933 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.04s
#
# Root relaxation: objective 9.387505e+03, 7855 iterations, 0.06 seconds (0.11 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    9387.5046593 9387.50466  0.00%     -    0s
#
# Explored 1 nodes (7855 simplex iterations) in 0.27 seconds (0.36 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 9387.5 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.387504659297e+03, best bound 9.387504659297e+03, gap 0.0000%
# 234339163.74843115 9387.50465929741
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0xc38f69a8
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [7e-06, 8e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 8e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 272096 columns
# Presolve time: 0.08s
# Presolved: 1031 rows, 8955 columns, 17901 nonzeros
# Variable types: 0 continuous, 8955 integer (8955 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 1.002533e+00, 9047 iterations, 0.13 seconds (0.26 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.00253    0  206   -0.00000    1.00253      -     -    0s
# H    0     0                       0.8903184    1.00253  12.6%     -    0s
# H    0     0                       0.9275578    1.00253  8.08%     -    0s
# H    0     0                       0.9665071    1.00253  3.73%     -    0s
# H    0     0                       0.9989453    1.00253  0.36%     -    0s
# H    0     0                       1.0000000    1.00253  0.25%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Zero half: 6
#
# Explored 1 nodes (9047 simplex iterations) in 0.50 seconds (0.62 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 6: 1 0.998945 0.966507 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# 234339163.74843115 9387.50465929741
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x6c3fe40c
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [2e-20, 8e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 8e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271959 columns
# Presolve time: 0.09s
# Presolved: 1031 rows, 9092 columns, 18038 nonzeros
# Found heuristic solution: objective 0.0000000
# Variable types: 0 continuous, 9092 integer (9092 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 1.001293e+00, 8459 iterations, 0.11 seconds (0.20 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.00129    0  239    0.00000    1.00129      -     -    0s
# H    0     0                       0.9038943    1.00129  10.8%     -    0s
# H    0     0                       0.9171323    1.00129  9.18%     -    0s
# H    0     0                       0.9679377    1.00129  3.45%     -    0s
# H    0     0                       0.9689090    1.00129  3.34%     -    0s
# H    0     0                       0.9780786    1.00129  2.37%     -    0s
# H    0     0                       0.9976758    1.00129  0.36%     -    0s
# H    0     0                       0.9987200    1.00129  0.26%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Zero half: 7
#
# Explored 1 nodes (8459 simplex iterations) in 0.46 seconds (0.56 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 8: 0.99872 0.997676 0.978079 ... 1.08505e-10
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.987199749992e-01, best bound 9.987199750029e-01, gap 0.0000%
# 234339163.74843115 9387.50465929741
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x26313f97
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [9e-20, 7e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 8e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271957 columns
# Presolve time: 0.11s
# Presolved: 1031 rows, 9094 columns, 18040 nonzeros
# Variable types: 0 continuous, 9094 integer (9094 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.04s
#
# Root relaxation: objective 9.963350e-01, 8457 iterations, 0.11 seconds (0.19 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.99634    0  239   -0.00000    0.99634      -     -    0s
# H    0     0                       0.9319139    0.99634  6.91%     -    0s
# H    0     0                       0.9626083    0.99634  3.50%     -    0s
# H    0     0                       0.9925979    0.99634  0.38%     -    0s
# H    0     0                       0.9935999    0.99634  0.28%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Zero half: 5
#
# Explored 1 nodes (8457 simplex iterations) in 0.55 seconds (0.54 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 0.9936 0.992598 0.962608 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.935998749960e-01, best bound 9.935998750144e-01, gap 0.0000%
# 234339163.74843115 9387.50465929741
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x1a7908f0
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [2e-19, 7e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 8e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271956 columns
# Presolve time: 0.09s
# Presolved: 1031 rows, 9095 columns, 18041 nonzeros
# Variable types: 0 continuous, 9095 integer (9095 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 9.901374e-01, 8392 iterations, 0.10 seconds (0.19 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.99014    0  239   -0.00000    0.99014      -     -    0s
# H    0     0                       0.8815537    0.99014  12.3%     -    0s
# H    0     0                       0.8831870    0.99014  12.1%     -    0s
# H    0     0                       0.9522824    0.99014  3.98%     -    0s
# H    0     0                       0.9840426    0.99014  0.62%     -    0s
# H    0     0                       0.9862505    0.99014  0.39%     -    0s
# H    0     0                       0.9871998    0.99014  0.30%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Zero half: 14
#
# Explored 1 nodes (8393 simplex iterations) in 0.45 seconds (0.52 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 7: 0.9872 0.986251 0.984043 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.871997499919e-01, best bound 9.871997500289e-01, gap 0.0000%
# 234339163.74843115 9387.50465929741
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x2addadd1
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [4e-19, 6e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 8e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271956 columns
# Presolve time: 0.09s
# Presolved: 1031 rows, 9095 columns, 18041 nonzeros
# Variable types: 0 continuous, 9095 integer (9095 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 9.783441e-01, 8377 iterations, 0.10 seconds (0.19 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.97834    0  244   -0.00000    0.97834      -     -    0s
# H    0     0                       0.9185558    0.97834  6.51%     -    0s
# H    0     0                       0.9189974    0.97834  6.46%     -    0s
# H    0     0                       0.9255403    0.97834  5.71%     -    0s
# H    0     0                       0.9735558    0.97834  0.49%     -    0s
# *    0     0               0       0.9749017    0.97490  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Zero half: 2
#   RLT: 9
#
# Explored 1 nodes (8403 simplex iterations) in 0.46 seconds (0.53 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 6: 0.974902 0.973556 0.92554 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.749016945372e-01, best bound 9.749016946110e-01, gap 0.0000%
# 234339163.74843115 9387.50465929741
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x5f471944
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [6e-19, 5e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 8e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271955 columns
# Presolve time: 0.09s
# Presolved: 1031 rows, 9096 columns, 18042 nonzeros
# Variable types: 0 continuous, 9096 integer (9096 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 9.680716e-01, 8181 iterations, 0.10 seconds (0.19 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.96807    0  226   -0.00000    0.96807      -     -    0s
# H    0     0                       0.8396859    0.96807  15.3%     -    0s
# H    0     0                       0.8508208    0.96807  13.8%     -    0s
# H    0     0                       0.9352005    0.96807  3.51%     -    0s
# H    0     0                       0.9374926    0.96807  3.26%     -    0s
# H    0     0                       0.9634469    0.96807  0.48%     -    0s
# H    0     0                       0.9657721    0.96807  0.24%     -    0s
# H    0     0                       0.9657983    0.96807  0.24%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Zero half: 3
#   RLT: 14
#
# Explored 1 nodes (8181 simplex iterations) in 0.48 seconds (0.54 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 8: 0.965798 0.965772 0.963447 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.657982633430e-01, best bound 9.657982633469e-01, gap 0.0000%
# 234339163.74843115 9387.50465929741
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0xf5bb4bad
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [7e-19, 5e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 8e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271955 columns
# Presolve time: 0.09s
# Presolved: 1031 rows, 9096 columns, 18042 nonzeros
# Variable types: 0 continuous, 9096 integer (9096 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 9.612127e-01, 8248 iterations, 0.10 seconds (0.19 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9612127    0.96121  0.00%     -    0s
#
# Explored 1 nodes (8248 simplex iterations) in 0.31 seconds (0.43 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 0.961213 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.612126743395e-01, best bound 9.612126743448e-01, gap 0.0000%
# 234339163.74843115 9387.50465929741
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x819fe79e
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [9e-19, 7e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 8e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271955 columns
# Presolve time: 0.08s
# Presolved: 1031 rows, 9096 columns, 18042 nonzeros
# Variable types: 0 continuous, 9096 integer (9096 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 9.591775e-01, 8079 iterations, 0.09 seconds (0.17 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9591775    0.95918  0.00%     -    0s
#
# Explored 1 nodes (8079 simplex iterations) in 0.29 seconds (0.41 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 0.959178 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.591775008502e-01, best bound 9.591775008567e-01, gap 0.0000%
# 234339163.74843115 9387.50465929741
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x57e82955
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [1e-18, 8e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 8e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271955 columns
# Presolve time: 0.08s
# Presolved: 1031 rows, 9096 columns, 18042 nonzeros
# Variable types: 0 continuous, 9096 integer (9096 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.08s
#
# Root relaxation: objective 9.571423e-01, 8065 iterations, 0.09 seconds (0.16 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9571423    0.95714  0.00%     -    0s
#
# Explored 1 nodes (8065 simplex iterations) in 0.35 seconds (0.40 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 0.957142 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.571423273608e-01, best bound 9.571423273687e-01, gap 0.0000%
# 234339163.74843115 9387.50465929741
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0xcd15d58f
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [1e-18, 9e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 8e+00]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271955 columns
# Presolve time: 0.08s
# Presolved: 1031 rows, 9096 columns, 18042 nonzeros
# Variable types: 0 continuous, 9096 integer (9096 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 9.579361e-01, 8003 iterations, 0.08 seconds (0.14 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# ...
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x0dacae06
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [7e-19, 5e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271955 columns
# Presolve time: 0.08s
# Presolved: 1031 rows, 9096 columns, 18042 nonzeros
# Variable types: 0 continuous, 9096 integer (9096 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 9.858376e-01, 8069 iterations, 0.15 seconds (0.28 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.98584    0  240   -0.00000    0.98584      -     -    0s
# H    0     0                       0.7390355    0.98584  33.4%     -    0s
# H    0     0                       0.7958071    0.98584  23.9%     -    0s
# H    0     0                       0.8155834    0.98584  20.9%     -    0s
# H    0     0                       0.9370388    0.98584  5.21%     -    0s
# H    0     0                       0.9505098    0.98584  3.72%     -    0s
# H    0     0                       0.9828000    0.98584  0.31%     -    0s
#      0     0    0.98413    0  214    0.98280    0.98413  0.14%     -    0s
#      0     0    0.98413    0  144    0.98280    0.98413  0.14%     -    0s
#      0     0    0.98413    0  145    0.98280    0.98413  0.14%     -    0s
# *    0     0               0       0.9838475    0.98385  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 4
#   Zero half: 9
#   RLT: 1
#
# Explored 1 nodes (9210 simplex iterations) in 0.69 seconds (0.83 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 8: 0.983847 0.9828 0.95051 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.838474816178e-01, best bound 9.838474816228e-01, gap 0.0000%
# 288596297.5792117 12594.841600480042
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x042f54fb
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [8e-19, 6e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271955 columns
# Presolve time: 0.08s
# Presolved: 1031 rows, 9096 columns, 18042 nonzeros
# Variable types: 0 continuous, 9096 integer (9096 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 9.867879e-01, 7785 iterations, 0.12 seconds (0.22 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.98679    0  232   -0.00000    0.98679      -     -    0s
# H    0     0                       0.8091838    0.98679  21.9%     -    0s
# H    0     0                       0.9223947    0.98679  6.98%     -    0s
# H    0     0                       0.9294015    0.98679  6.17%     -    0s
# H    0     0                       0.9851930    0.98679  0.16%     -    0s
# H    0     0                       0.9853329    0.98679  0.15%     -    0s
#      0     0    0.98633    0  321    0.98533    0.98633  0.10%     -    0s
# H    0     0                       0.9855501    0.98633  0.08%     -    0s
#      0     0          -    0         0.98555    0.98561  0.01%     -    0s
#
# Explored 1 nodes (7884 simplex iterations) in 0.72 seconds (0.83 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 8: 0.98555 0.985333 0.985193 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.855501088010e-01, best bound 9.856109578392e-01, gap 0.0062%
# 288596297.5792117 12594.841600480042
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0xa392f366
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [1e-18, 7e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271955 columns
# Presolve time: 0.08s
# Presolved: 1031 rows, 9096 columns, 18042 nonzeros
# Variable types: 0 continuous, 9096 integer (9096 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 9.883888e-01, 7895 iterations, 0.12 seconds (0.23 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.98839    0  278   -0.00000    0.98839      -     -    0s
# H    0     0                       0.6517850    0.98839  51.6%     -    0s
# H    0     0                       0.8921103    0.98839  10.8%     -    0s
# H    0     0                       0.8928959    0.98839  10.7%     -    0s
# H    0     0                       0.8938978    0.98839  10.6%     -    0s
# H    0     0                       0.8964137    0.98839  10.3%     -    0s
# H    0     0                       0.8964301    0.98839  10.3%     -    0s
# H    0     0                       0.9872942    0.98839  0.11%     -    0s
# H    0     0                       0.9874211    0.98839  0.10%     -    0s
# H    0     0                       0.9879976    0.98839  0.04%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Zero half: 1
#
# Explored 1 nodes (7895 simplex iterations) in 0.52 seconds (0.62 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 0.987998 0.987421 0.987294 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.879976495520e-01, best bound 9.879976495589e-01, gap 0.0000%
# 288596297.5792117 12594.841600480042
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0xb0a576df
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [1e-18, 8e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271955 columns
# Presolve time: 0.08s
# Presolved: 1031 rows, 9096 columns, 18042 nonzeros
# Variable types: 0 continuous, 9096 integer (9096 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 9.907710e-01, 8169 iterations, 0.13 seconds (0.25 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.99077    0  291   -0.00000    0.99077      -     -    0s
# H    0     0                       0.6318639    0.99077  56.8%     -    0s
# H    0     0                       0.8534154    0.99077  16.1%     -    0s
# H    0     0                       0.9460098    0.99077  4.73%     -    0s
# H    0     0                       0.9472103    0.99077  4.60%     -    0s
# H    0     0                       0.9899932    0.99077  0.08%     -    0s
# H    0     0                       0.9906624    0.99077  0.01%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Zero half: 12
#
# Explored 1 nodes (8169 simplex iterations) in 0.49 seconds (0.62 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 7: 0.990662 0.989993 0.94721 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.906624183969e-01, best bound 9.907184459895e-01, gap 0.0057%
# 288596297.5792117 12594.841600480042
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x75853398
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [1e-18, 9e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271955 columns
# Presolve time: 0.08s
# Presolved: 1031 rows, 9096 columns, 18042 nonzeros
# Variable types: 0 continuous, 9096 integer (9096 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 9.936604e-01, 9377 iterations, 0.17 seconds (0.29 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.99366    0  323   -0.00000    0.99366      -     -    0s
# H    0     0                       0.6119463    0.99366  62.4%     -    0s
# H    0     0                       0.9441045    0.99366  5.25%     -    0s
# H    0     0                       0.9480966    0.99366  4.81%     -    0s
# H    0     0                       0.9864259    0.99366  0.73%     -    0s
# H    0     0                       0.9864919    0.99366  0.73%     -    0s
# H    0     0                       0.9869518    0.99366  0.68%     -    0s
# H    0     0                       0.9876886    0.99366  0.60%     -    0s
# H    0     0                       0.9877666    0.99366  0.60%     -    0s
# H    0     0                       0.9933269    0.99366  0.03%     -    0s
# H    0     0                       0.9933271    0.99360  0.03%     -    0s
#      0     0    0.99357    0  301    0.99333    0.99357  0.02%     -    0s
# H    0     0                       0.9933272    0.99357  0.02%     -    0s
#      0     0          -    0         0.99333    0.99334  0.00%     -    0s
#
# Explored 1 nodes (9395 simplex iterations) in 0.65 seconds (0.76 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 0.993327 0.993327 0.993327 ... 0.944104
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.933271872419e-01, best bound 9.933419050507e-01, gap 0.0015%
# 288596297.5792117 12594.841600480042
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x54213ebe
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [1e-18, 1e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271955 columns
# Presolve time: 0.08s
# Presolved: 1031 rows, 9096 columns, 18042 nonzeros
# Variable types: 0 continuous, 9096 integer (9096 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 9.959409e-01, 10010 iterations, 0.21 seconds (0.35 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.99594    0  228   -0.00000    0.99594      -     -    0s
# H    0     0                       0.9445620    0.99594  5.44%     -    0s
# H    0     0                       0.9732154    0.99594  2.34%     -    0s
# H    0     0                       0.9823272    0.99594  1.39%     -    0s
# H    0     0                       0.9884439    0.99594  0.76%     -    0s
# H    0     0                       0.9953235    0.99594  0.06%     -    0s
# H    0     0                       0.9953237    0.99549  0.02%     -    0s
#      0     0    0.99549    0  247    0.99532    0.99549  0.02%     -    0s
#      0     0          -    0         0.99532    0.99537  0.00%     -    0s
#
# Explored 1 nodes (10052 simplex iterations) in 0.65 seconds (0.81 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 8: 0.995324 0.995324 0.995323 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.953237411186e-01, best bound 9.953673997350e-01, gap 0.0044%
# 288596297.5792117 12594.841600480042
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x443393c5
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [1e-18, 1e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280021 rows and 271955 columns
# Presolve time: 0.08s
# Presolved: 1031 rows, 9096 columns, 18042 nonzeros
# Variable types: 0 continuous, 9096 integer (9096 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 9.990631e-01, 9598 iterations, 0.19 seconds (0.31 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9990631    0.99906  0.00%     -    0s
#
# Explored 1 nodes (9598 simplex iterations) in 0.38 seconds (0.55 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 0.999063 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.990631166856e-01, best bound 9.990631166953e-01, gap 0.0000%
# 288596297.5792117 12594.841600480042
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0xecdb4600
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [1e-18, 1e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280023 rows and 272144 columns
# Presolve time: 0.08s
# Presolved: 1029 rows, 8907 columns, 17664 nonzeros
# Variable types: 0 continuous, 8907 integer (8907 binary)
# Performing another presolve...
# Presolve removed 9 rows and 9 columns
# Presolve time: 0.03s
#
# Root relaxation: objective 9.999999e-01, 6979 iterations, 0.14 seconds (0.22 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9999999    1.00000  0.00%     -    0s
#
# Explored 1 nodes (6979 simplex iterations) in 0.33 seconds (0.47 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 1 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.999998713067e-01, best bound 9.999998713165e-01, gap 0.0000%
# N_f Analysis: 100%|██████████| 8/8 [08:59<00:00, 67.41s/it]

# %%
# --- 分析2: ドローン航続距離 L_drone の感度分析 ---
logging.info("--- Starting Sensitivity Analysis for Drone Endurance (L_drone) ---")
l_drone_list = [1, 2, 3, 4]
l_drone_results = []
# 施設数はデフォルト値（12）に固定
base_params['NUM_OPEN_FACILITIES'] = 12 

for l_drone in tqdm(l_drone_list, desc="L_drone Analysis"):
    logging.info(f"--- Running for L_drone = {l_drone} km ---")
    current_params = base_params.copy()
    current_params['UAV_ENDURANCE'] = l_drone
    
    # 航続距離が変わると収益性も変わるため再計算
    ITEM_PRICE_MARGIN = 20 * 164.48
    FIX_COST = 1 * 164.48
    MAX_DELIVERY_COST = 1 * 164.48
    profit_per_person = ITEM_PRICE_MARGIN - FIX_COST - (MAX_DELIVERY_COST * current_params['DISTANCE_F_D'] / l_drone)
    current_params['PROFITABILITY_F_D'] = current_params['POPULATION_D'][np.newaxis, :] * profit_per_person

    results_for_ldrone = run_single_scenario(current_params)
    for res in results_for_ldrone:
        res['l_drone'] = l_drone
    l_drone_results.extend(results_for_ldrone)
    
all_results_collection['l_drone_analysis'] = pd.DataFrame(l_drone_results)
logging.info("--- Finished L_drone analysis ---")

end_time = time.time()
logging.info(f"Total execution time: {end_time - start_time:.2f} seconds.")
# Out:
# L_drone Analysis:   0%|          | 0/4 [00:00<?, ?it/s]
# 1.0 1.0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0xeb04bca1
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [6e-02, 2e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280253 rows and 279157 columns
# Presolve time: 0.09s
# Presolved: 799 rows, 1894 columns, 3608 nonzeros
# Variable types: 0 continuous, 1894 integer (1894 binary)
# Performing another presolve...
# Presolve removed 414 rows and 857 columns
# Presolve time: 0.02s
#
# Root relaxation: objective 1.627296e+08, 600 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1.627296e+08 1.6273e+08 -0.00%     -    0s
#
# Explored 1 nodes (600 simplex iterations) in 0.21 seconds (0.21 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 1.6273e+08 -0 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.627296122709e+08, best bound 1.627296122709e+08, gap 0.0000%
# 1.0 1.0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0xf6b92825
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [2e-14, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280293 rows and 279194 columns
# Presolve time: 0.08s
# Presolved: 759 rows, 1857 columns, 3466 nonzeros
# Variable types: 0 continuous, 1857 integer (1857 binary)
# Performing another presolve...
# Presolve removed 405 rows and 885 columns
# Presolve time: 0.02s
#
# Root relaxation: objective 6.608264e+03, 520 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    6608.2639328 6608.26393  0.00%     -    0s
#
# Explored 1 nodes (520 simplex iterations) in 0.17 seconds (0.21 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 6608.26 1.73442e-14 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.608263932804e+03, best bound 6.608263932804e+03, gap 0.0000%
# 162729612.270917 6608.263932804286
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0xed125199
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [3e-10, 1e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280253 rows and 279157 columns
# Presolve time: 0.09s
# Presolved: 799 rows, 1894 columns, 3608 nonzeros
# Variable types: 0 continuous, 1894 integer (1894 binary)
# Performing another presolve...
# Presolve removed 414 rows and 857 columns
# Presolve time: 0.02s
#
# Root relaxation: objective 1.000000e+00, 600 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       1.0000000    1.00000  0.00%     -    0s
#
# Explored 1 nodes (600 simplex iterations) in 0.18 seconds (0.21 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 1 -0 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# 162729612.270917 6608.263932804286
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x7435cd84
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [3e-20, 1e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280253 rows and 279130 columns
# Presolve time: 0.08s
# Presolved: 799 rows, 1921 columns, 3635 nonzeros
# Variable types: 0 continuous, 1921 integer (1921 binary)
# Performing another presolve...
# Presolve removed 414 rows and 864 columns
# Presolve time: 0.02s
#
# Root relaxation: objective 9.959471e-01, 266 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9959471    0.99595  0.00%     -    0s
#
# Explored 1 nodes (266 simplex iterations) in 0.17 seconds (0.21 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 0.995947 5.03754e-11 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.959471013885e-01, best bound 9.959471014092e-01, gap 0.0000%
# 162729612.270917 6608.263932804286
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x9c31bc61
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [1e-19, 1e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280253 rows and 279129 columns
# Presolve time: 0.08s
# Presolved: 799 rows, 1922 columns, 3636 nonzeros
# Found heuristic solution: objective 0.0000000
# Variable types: 0 continuous, 1922 integer (1922 binary)
# Performing another presolve...
# Presolve removed 414 rows and 864 columns
# Presolve time: 0.02s
#
# Root relaxation: objective 9.808604e-01, 263 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9808604    0.98086  0.00%     -    0s
#
# Explored 1 nodes (263 simplex iterations) in 0.17 seconds (0.21 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 0.98086 1.03919e-10 1.03919e-10
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.808603980871e-01, best bound 9.808603981911e-01, gap 0.0000%
# 162729612.270917 6608.263932804286
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x6e22f872
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [3e-19, 1e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280253 rows and 279128 columns
# Presolve time: 0.08s
# Presolved: 799 rows, 1923 columns, 3637 nonzeros
# Variable types: 0 continuous, 1923 integer (1923 binary)
# Performing another presolve...
# Presolve removed 414 rows and 864 columns
# Presolve time: 0.02s
#
# Root relaxation: objective 9.620020e-01, 255 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9620020    0.96200  0.00%     -    0s
#
# Explored 1 nodes (255 simplex iterations) in 0.16 seconds (0.21 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 0.962002 5.24499e-11 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.620020189605e-01, best bound 9.620020190130e-01, gap 0.0000%
# 162729612.270917 6608.263932804286
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0xd37c0cd5
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [5e-19, 9e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280253 rows and 279128 columns
# Presolve time: 0.08s
# Presolved: 799 rows, 1923 columns, 3637 nonzeros
# Variable types: 0 continuous, 1923 integer (1923 binary)
# Performing another presolve...
# Presolve removed 414 rows and 864 columns
# Presolve time: 0.02s
#
# Root relaxation: objective 9.283934e-01, 243 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9283934    0.92839  0.00%     -    0s
#
# Explored 1 nodes (243 simplex iterations) in 0.17 seconds (0.21 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 0.928393 3.74478e-12 -0
# No other solutions better than 0.928393
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.283934366996e-01, best bound 9.283934367034e-01, gap 0.0000%
# 162729612.270917 6608.263932804286
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0xaca4e40a
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [8e-19, 8e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280253 rows and 279128 columns
# Presolve time: 0.08s
# Presolved: 799 rows, 1923 columns, 3637 nonzeros
# Variable types: 0 continuous, 1923 integer (1923 binary)
# Performing another presolve...
# Presolve removed 414 rows and 864 columns
# Presolve time: 0.02s
#
# Root relaxation: objective 9.088845e-01, 244 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9088845    0.90888  0.00%     -    0s
#
# Explored 1 nodes (244 simplex iterations) in 0.17 seconds (0.21 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 0.908884 5.61716e-12 -0
# No other solutions better than 0.908884
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.088844824366e-01, best bound 9.088844824422e-01, gap 0.0000%
# 162729612.270917 6608.263932804286
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x5b56355c
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [1e-18, 8e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280253 rows and 279128 columns
# Presolve time: 0.08s
# Presolved: 799 rows, 1923 columns, 3637 nonzeros
# Variable types: 0 continuous, 1923 integer (1923 binary)
# Performing another presolve...
# Presolve removed 414 rows and 864 columns
# Presolve time: 0.02s
#
# Root relaxation: objective 8.970340e-01, 229 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.8970340    0.89703  0.00%     -    0s
#
# Explored 1 nodes (229 simplex iterations) in 0.16 seconds (0.21 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 0.897034 7.48955e-12 -0
# No other solutions better than 0.897034
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.970340130449e-01, best bound 8.970340130524e-01, gap 0.0000%
# 162729612.270917 6608.263932804286
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x798ed6f7
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [1e-18, 1e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280253 rows and 279128 columns
# Presolve time: 0.08s
# Presolved: 799 rows, 1923 columns, 3637 nonzeros
# Variable types: 0 continuous, 1923 integer (1923 binary)
# Performing another presolve...
# Presolve removed 414 rows and 864 columns
# Presolve time: 0.02s
#
# Root relaxation: objective 8.918192e-01, 235 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.8918192    0.89182  0.00%     -    0s
#
# Explored 1 nodes (235 simplex iterations) in 0.17 seconds (0.21 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 0.891819 9.36194e-12 -0
# No other solutions better than 0.891819
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.918192182866e-01, best bound 8.918192182960e-01, gap 0.0000%
# 162729612.270917 6608.263932804286
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x25699ae6
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [2e-18, 1e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280253 rows and 279128 columns
# Presolve time: 0.08s
# Presolved: 799 rows, 1923 columns, 3637 nonzeros
# Variable types: 0 continuous, 1923 integer (1923 binary)
# Performing another presolve...
# Presolve removed 414 rows and 864 columns
# Presolve time: 0.02s
#
# Root relaxation: objective 8.899499e-01, 236 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.8899499    0.88995  0.00%     -    0s
#
# Explored 1 nodes (236 simplex iterations) in 0.17 seconds (0.21 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 0.88995 1.12343e-11 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.899498987097e-01, best bound 8.899498987210e-01, gap 0.0000%
# 162729612.270917 6608.263932804286
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x95a16107
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [2e-18, 1e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280253 rows and 279128 columns
# Presolve time: 0.08s
# Presolved: 799 rows, 1923 columns, 3637 nonzeros
# Variable types: 0 continuous, 1923 integer (1923 binary)
# Performing another presolve...
# Presolve removed 414 rows and 864 columns
# Presolve time: 0.02s
#
# Root relaxation: objective 8.981609e-01, 234 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.8981609    0.89816  0.00%     -    0s
#
# Explored 1 nodes (234 simplex iterations) in 0.17 seconds (0.21 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 0.898161 1.31067e-11 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.981609363560e-01, best bound 8.981609363691e-01, gap 0.0000%
# 162729612.270917 6608.263932804286
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x3c2b5871
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [2e-18, 2e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280253 rows and 279128 columns
# Presolve time: 0.08s
# Presolved: 799 rows, 1923 columns, 3637 nonzeros
# Variable types: 0 continuous, 1923 integer (1923 binary)
# Performing another presolve...
# Presolve removed 414 rows and 864 columns
# Presolve time: 0.02s
#
# Root relaxation: objective 9.101743e-01, 232 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9101743    0.91017  0.00%     -    0s
#
# Explored 1 nodes (232 simplex iterations) in 0.16 seconds (0.21 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 0.910174 1.49791e-11 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.101742702611e-01, best bound 9.101742702761e-01, gap 0.0000%
# 162729612.270917 6608.263932804286
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x367a0ff4
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [2e-18, 2e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280253 rows and 279128 columns
# Presolve time: 0.08s
# Presolved: 799 rows, 1923 columns, 3637 nonzeros
# Variable types: 0 continuous, 1923 integer (1923 binary)
# Performing another presolve...
# Presolve removed 414 rows and 864 columns
# Presolve time: 0.02s
#
# Root relaxation: objective 9.413216e-01, 233 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9413216    0.94132  0.00%     -    0s
#
# Explored 1 nodes (233 simplex iterations) in 0.20 seconds (0.21 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 0.941322 1.68515e-11 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.413216064723e-01, best bound 9.413216064891e-01, gap 0.0000%
# 162729612.270917 6608.263932804286
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x340f49e4
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [2e-18, 2e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280253 rows and 279128 columns
# Presolve time: 0.09s
# Presolved: 799 rows, 1923 columns, 3637 nonzeros
# Variable types: 0 continuous, 1923 integer (1923 binary)
# Performing another presolve...
# Presolve removed 414 rows and 864 columns
# Presolve time: 0.02s
#
# Root relaxation: objective 9.706608e-01, 228 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9706608    0.97066  0.00%     -    0s
#
# Explored 1 nodes (228 simplex iterations) in 0.18 seconds (0.21 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 0.970661 1.77877e-11 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.706608032361e-01, best bound 9.706608032539e-01, gap 0.0000%
# 162729612.270917 6608.263932804286
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x66b9784d
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [3e-18, 2e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280253 rows and 279128 columns
# Presolve time: 0.08s
# Presolved: 799 rows, 1923 columns, 3637 nonzeros
# Variable types: 0 continuous, 1923 integer (1923 binary)
# Performing another presolve...
# Presolve removed 414 rows and 864 columns
# Presolve time: 0.02s
#
# Root relaxation: objective 9.941322e-01, 222 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9941322    0.99413  0.00%     -    0s
#
# Explored 1 nodes (222 simplex iterations) in 0.17 seconds (0.21 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 0.994132 1.85366e-11 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.941321606472e-01, best bound 9.941321606658e-01, gap 0.0000%
# 162729612.270917 6608.263932804286
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0xc2785ed1
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [3e-18, 2e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280296 rows and 279196 columns
# Presolve time: 0.08s
# Presolved: 756 rows, 1855 columns, 3460 nonzeros
# Variable types: 0 continuous, 1855 integer (1855 binary)
# Performing another presolve...
# Presolve removed 402 rows and 883 columns
# Presolve time: 0.02s
#
# Root relaxation: objective 1.000000e+00, 507 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       1.0000000    1.00000  0.00%     -    0s
#
# Explored 1 nodes (507 simplex iterations) in 0.16 seconds (0.21 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 1 1.87239e-11 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000019e+00, gap 0.0000%
# L_drone Analysis:  25%|██▌       | 1/4 [01:03<03:09, 63.06s/it]
# 1.0 1.0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0xa256a23a
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [2e+00, 2e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280053 rows and 276223 columns
# Presolve time: 0.09s
# Presolved: 999 rows, 4828 columns, 9632 nonzeros
# Variable types: 0 continuous, 4828 integer (4828 binary)
# Performing another presolve...
# Presolve removed 19 rows and 23 columns
# Presolve time: 0.02s
#
# Root relaxation: objective 2.251558e+08, 3897 iterations, 0.03 seconds (0.05 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2.2516e+08    0   47   -0.00000 2.2516e+08      -     -    0s
# H    0     0                    2.006139e+08 2.2516e+08  12.2%     -    0s
# H    0     0                    2.012928e+08 2.2516e+08  11.9%     -    0s
# H    0     0                    2.086764e+08 2.2516e+08  7.90%     -    0s
# H    0     0                    2.159878e+08 2.2516e+08  4.24%     -    0s
# H    0     0                    2.161265e+08 2.2516e+08  4.18%     -    0s
# H    0     0                    2.244054e+08 2.2516e+08  0.33%     -    0s
#
# Explored 1 nodes (3897 simplex iterations) in 0.25 seconds (0.29 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 7: 2.24405e+08 2.16126e+08 2.15988e+08 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.244054033564e+08, best bound 2.244054033564e+08, gap 0.0000%
# 1.0 1.0
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x0af0af1a
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [2e-14, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280054 rows and 276226 columns
# Presolve time: 0.09s
# Presolved: 998 rows, 4825 columns, 9523 nonzeros
# Variable types: 0 continuous, 4825 integer (4825 binary)
# Performing another presolve...
# Presolve removed 19 rows and 23 columns
# Presolve time: 0.02s
#
# Root relaxation: objective 8.971033e+03, 3829 iterations, 0.02 seconds (0.04 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    8971.0333405 8971.03334  0.00%     -    0s
#
# Explored 1 nodes (3829 simplex iterations) in 0.20 seconds (0.25 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 8971.03 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.971033340514e+03, best bound 8.971033340514e+03, gap 0.0000%
# 224405403.3563561 8971.03334051435
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0xa1dad0a2
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [1e-08, 8e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280053 rows and 276223 columns
# Presolve time: 0.09s
# Presolved: 999 rows, 4828 columns, 9632 nonzeros
# Variable types: 0 continuous, 4828 integer (4828 binary)
# Performing another presolve...
# Presolve removed 19 rows and 23 columns
# Presolve time: 0.02s
#
# Root relaxation: objective 1.003344e+00, 3891 iterations, 0.03 seconds (0.05 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.00334    0   47   -0.00000    1.00334      -     -    0s
# H    0     0                       0.8939796    1.00334  12.2%     -    0s
# H    0     0                       0.8970052    1.00334  11.9%     -    0s
# H    0     0                       0.9299081    1.00334  7.90%     -    0s
# H    0     0                       0.9624891    1.00334  4.24%     -    0s
# H    0     0                       0.9631074    1.00334  4.18%     -    0s
# H    0     0                       1.0000000    1.00334  0.33%     -    0s
#      0     0     cutoff    0         1.00000    1.00000  0.00%     -    0s
#
# Explored 1 nodes (3893 simplex iterations) in 0.25 seconds (0.29 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 7: 1 0.963107 0.962489 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+00, best bound 1.000000000000e+00, gap 0.0000%
# 224405403.3563561 8971.03334051435
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0xf3b0258c
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [2e-20, 8e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280053 rows and 276124 columns
# Presolve time: 0.08s
# Presolved: 999 rows, 4927 columns, 9731 nonzeros
# Found heuristic solution: objective 0.0000000
# Variable types: 0 continuous, 4927 integer (4927 binary)
# Performing another presolve...
# Presolve removed 19 rows and 23 columns
# Presolve time: 0.02s
#
# Root relaxation: objective 1.001711e+00, 4102 iterations, 0.03 seconds (0.05 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.00171    0   53    0.00000    1.00171      -     -    0s
# H    0     0                       0.8926901    1.00171  12.2%     -    0s
# H    0     0                       0.9158228    1.00171  9.38%     -    0s
# H    0     0                       0.9602766    1.00171  4.31%     -    0s
# H    0     0                       0.9824237    1.00171  1.96%     -    0s
# H    0     0                       0.9867195    1.00171  1.52%     -    0s
# H    0     0                       0.9983515    1.00171  0.34%     -    0s
#      0     0          -    0         0.99835    0.99845  0.01%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   RLT: 1
#
# Explored 1 nodes (4104 simplex iterations) in 0.26 seconds (0.29 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 7: 0.998351 0.986719 0.982424 ... 1.13542e-10
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.983514756845e-01, best bound 9.984454693773e-01, gap 0.0094%
# 224405403.3563561 8971.03334051435
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x629dbc7c
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [1e-19, 8e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280053 rows and 276122 columns
# Presolve time: 0.08s
# Presolved: 999 rows, 4929 columns, 9733 nonzeros
# Variable types: 0 continuous, 4929 integer (4929 binary)
# Performing another presolve...
# Presolve removed 19 rows and 23 columns
# Presolve time: 0.02s
#
# Root relaxation: objective 9.951794e-01, 3974 iterations, 0.03 seconds (0.05 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.99518    0   53   -0.00000    0.99518      -     -    0s
# H    0     0                       0.9126794    0.99518  9.04%     -    0s
# H    0     0                       0.9504858    0.99518  4.70%     -    0s
# H    0     0                       0.9528622    0.99518  4.44%     -    0s
# H    0     0                       0.9794796    0.99518  1.60%     -    0s
# H    0     0                       0.9917574    0.99518  0.35%     -    0s
# *    0     0               0       0.9924565    0.99246  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   RLT: 3
#
# Explored 1 nodes (3978 simplex iterations) in 0.25 seconds (0.29 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 7: 0.992457 0.991757 0.97948 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.924565039530e-01, best bound 9.924565040296e-01, gap 0.0000%
# 224405403.3563561 8971.03334051435
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x30b0f4bf
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [2e-19, 7e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280053 rows and 276121 columns
# Presolve time: 0.08s
# Presolved: 999 rows, 4930 columns, 9734 nonzeros
# Variable types: 0 continuous, 4930 integer (4930 binary)
# Performing another presolve...
# Presolve removed 19 rows and 23 columns
# Presolve time: 0.02s
#
# Root relaxation: objective 9.870147e-01, 3996 iterations, 0.02 seconds (0.04 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.98701    0   53   -0.00000    0.98701      -     -    0s
# H    0     0                       0.9042331    0.98701  9.15%     -    0s
# H    0     0                       0.9437985    0.98701  4.58%     -    0s
# H    0     0                       0.9452503    0.98701  4.42%     -    0s
# H    0     0                       0.9708538    0.98701  1.66%     -    0s
# H    0     0                       0.9835148    0.98701  0.36%     -    0s
# H    0     0                       0.9867000    0.98690  0.02%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   RLT: 3
#
# Explored 1 nodes (3996 simplex iterations) in 0.25 seconds (0.29 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 7: 0.9867 0.983515 0.970854 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.867000182971e-01, best bound 9.867000183358e-01, gap 0.0000%
# 224405403.3563561 8971.03334051435
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0xb35def7e
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [4e-19, 6e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280053 rows and 276121 columns
# Presolve time: 0.08s
# Presolved: 999 rows, 4930 columns, 9734 nonzeros
# Variable types: 0 continuous, 4930 integer (4930 binary)
# Performing another presolve...
# Presolve removed 19 rows and 23 columns
# Presolve time: 0.02s
#
# Root relaxation: objective 9.768771e-01, 3980 iterations, 0.02 seconds (0.04 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9768771    0.97688  0.00%     -    0s
#
# Explored 1 nodes (3980 simplex iterations) in 0.20 seconds (0.25 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 0.976877 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.768770767270e-01, best bound 9.768770768043e-01, gap 0.0000%
# 224405403.3563561 8971.03334051435
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0xee1ba93b
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [6e-19, 6e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280053 rows and 276121 columns
# Presolve time: 0.08s
# Presolved: 999 rows, 4930 columns, 9734 nonzeros
# Variable types: 0 continuous, 4930 integer (4930 binary)
# Performing another presolve...
# Presolve removed 19 rows and 23 columns
# Presolve time: 0.02s
#
# Root relaxation: objective 9.701757e-01, 3979 iterations, 0.02 seconds (0.04 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9701757    0.97018  0.00%     -    0s
#
# Explored 1 nodes (3979 simplex iterations) in 0.19 seconds (0.25 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 0.970176 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.701757358154e-01, best bound 9.701757358196e-01, gap 0.0000%
# 224405403.3563561 8971.03334051435
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x9ef11448
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [8e-19, 6e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280053 rows and 276121 columns
# Presolve time: 0.08s
# Presolved: 999 rows, 4930 columns, 9734 nonzeros
# Variable types: 0 continuous, 4930 integer (4930 binary)
# Performing another presolve...
# Presolve removed 19 rows and 23 columns
# Presolve time: 0.02s
#
# Root relaxation: objective 9.636842e-01, 3976 iterations, 0.02 seconds (0.04 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9636842    0.96368  0.00%     -    0s
#
# Explored 1 nodes (3976 simplex iterations) in 0.20 seconds (0.25 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 0.963684 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.636842045403e-01, best bound 9.636842045458e-01, gap 0.0000%
# 224405403.3563561 8971.03334051435
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0xcf98d682
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [1e-18, 7e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280053 rows and 276121 columns
# Presolve time: 0.08s
# Presolved: 999 rows, 4930 columns, 9734 nonzeros
# Variable types: 0 continuous, 4930 integer (4930 binary)
# Performing another presolve...
# Presolve removed 19 rows and 23 columns
# Presolve time: 0.02s
#
# Root relaxation: objective 9.573598e-01, 4015 iterations, 0.02 seconds (0.04 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9573598    0.95736  0.00%     -    0s
#
# Explored 1 nodes (4015 simplex iterations) in 0.20 seconds (0.26 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 0.95736 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.573597629991e-01, best bound 9.573597630060e-01, gap 0.0000%
# 224405403.3563561 8971.03334051435
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x61c885e4
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [1e-18, 9e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280053 rows and 276121 columns
# Presolve time: 0.08s
# Presolved: 999 rows, 4930 columns, 9734 nonzeros
# Variable types: 0 continuous, 4930 integer (4930 binary)
# Performing another presolve...
# Presolve removed 19 rows and 23 columns
# Presolve time: 0.02s
#
# Root relaxation: objective 9.510353e-01, 4008 iterations, 0.02 seconds (0.04 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9510353    0.95104  0.00%     -    0s
#
# Explored 1 nodes (4008 simplex iterations) in 0.20 seconds (0.26 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 0.951035 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.510353214579e-01, best bound 9.510353214662e-01, gap 0.0000%
# 224405403.3563561 8971.03334051435
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x84a52801
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [1e-18, 1e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280053 rows and 276121 columns
# Presolve time: 0.08s
# Presolved: 999 rows, 4930 columns, 9734 nonzeros
# Variable types: 0 continuous, 4930 integer (4930 binary)
# Performing another presolve...
# Presolve removed 19 rows and 23 columns
# Presolve time: 0.02s
#
# Root relaxation: objective 9.461268e-01, 4016 iterations, 0.02 seconds (0.04 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9461268    0.94613  0.00%     -    0s
#
# Explored 1 nodes (4016 simplex iterations) in 0.19 seconds (0.25 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 0.946127 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.461268462261e-01, best bound 9.461268462358e-01, gap 0.0000%
# 224405403.3563561 8971.03334051435
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x4f4c17ef
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [2e-18, 1e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280053 rows and 276121 columns
# Presolve time: 0.08s
# Presolved: 999 rows, 4930 columns, 9734 nonzeros
# Variable types: 0 continuous, 4930 integer (4930 binary)
# Performing another presolve...
# Presolve removed 19 rows and 23 columns
# Presolve time: 0.02s
#
# Root relaxation: objective 9.516695e-01, 3958 iterations, 0.02 seconds (0.04 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9516695    0.95167  0.00%     -    0s
#
# Explored 1 nodes (3958 simplex iterations) in 0.19 seconds (0.25 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 0.95167 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.516695407845e-01, best bound 9.516695407955e-01, gap 0.0000%
# 224405403.3563561 8971.03334051435
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0xb76d342b
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [2e-18, 1e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280053 rows and 276121 columns
# Presolve time: 0.08s
# Presolved: 999 rows, 4930 columns, 9734 nonzeros
# Variable types: 0 continuous, 4930 integer (4930 binary)
# Performing another presolve...
# Presolve removed 19 rows and 23 columns
# Presolve time: 0.02s
#
# Root relaxation: objective 9.701016e-01, 3921 iterations, 0.02 seconds (0.04 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.9701016    0.97010  0.00%     -    0s
#
# ...
# Presolve removed 5 rows and 5 columns
# Presolve time: 0.10s
#
# Root relaxation: objective 9.860659e-01, 13606 iterations, 0.38 seconds (0.76 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.98607    0  686   -0.00000    0.98607      -     -    0s
# H    0     0                       0.7123880    0.98607  38.4%     -    0s
# H    0     0                       0.9306347    0.98607  5.96%     -    0s
# H    0     0                       0.9306468    0.98607  5.95%     -    0s
# H    0     0                       0.9338488    0.98607  5.59%     -    0s
# H    0     0                       0.9624465    0.98607  2.45%     -    0s
# H    0     0                       0.9685562    0.98607  1.81%     -    0s
# H    0     0                       0.9855553    0.98607  0.05%     -    0s
# H    0     0                       0.9855579    0.98607  0.05%     -    1s
#      0     0    0.98569    0  606    0.98556    0.98569  0.01%     -    1s
#      0     0 infeasible    0         0.98556    0.98556  0.00%     -    1s
#
# Explored 1 nodes (13819 simplex iterations) in 1.26 seconds (1.64 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 0.985558 0.985555 0.984825 ... 0.930635
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.855579136994e-01, best bound 9.855579137053e-01, gap 0.0000%
# 288667970.20610076 12620.122134888936
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x9016b344
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [1e-18, 7e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [4e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280013 rows and 266541 columns
# Presolve time: 0.09s
# Presolved: 1039 rows, 14510 columns, 28846 nonzeros
# Variable types: 0 continuous, 14510 integer (14510 binary)
# Performing another presolve...
# Presolve removed 5 rows and 5 columns
# Presolve time: 0.06s
#
# Root relaxation: objective 9.872555e-01, 13292 iterations, 0.33 seconds (0.67 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.98726    0  371   -0.00000    0.98726      -     -    0s
# H    0     0                       0.9255125    0.98726  6.67%     -    0s
# H    0     0                       0.9418755    0.98726  4.82%     -    0s
# H    0     0                       0.9644731    0.98726  2.36%     -    0s
# H    0     0                       0.9795068    0.98726  0.79%     -    0s
# H    0     0                       0.9837393    0.98726  0.36%     -    0s
# H    0     0                       0.9853602    0.98726  0.19%     -    0s
# H    0     0                       0.9854820    0.98726  0.18%     -    0s
#      0     0    0.98677    0  573    0.98548    0.98677  0.13%     -    0s
#      0     0    0.98661    0  167    0.98548    0.98661  0.11%     -    1s
#      0     0    0.98624    0  157    0.98548    0.98624  0.08%     -    1s
# H    0     0                       0.9855024    0.98624  0.07%     -    1s
# H    0     0                       0.9855080    0.98624  0.07%     -    1s
# H    0     0                       0.9855089    0.98624  0.07%     -    1s
# H    0     0                       0.9857740    0.98624  0.05%     -    1s
#
# Cutting planes:
#   Gomory: 1
#   Clique: 28
#   Zero half: 3
#
# Explored 1 nodes (14214 simplex iterations) in 1.20 seconds (1.55 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 0.985774 0.985509 0.985508 ... 0.941876
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.857739826461e-01, best bound 9.857739826529e-01, gap 0.0000%
# 288667970.20610076 12620.122134888936
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0xa0abdbd1
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [1e-18, 8e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [4e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280013 rows and 266541 columns
# Presolve time: 0.08s
# Presolved: 1039 rows, 14510 columns, 28846 nonzeros
# Variable types: 0 continuous, 14510 integer (14510 binary)
# Performing another presolve...
# Presolve removed 5 rows and 5 columns
# Presolve time: 0.06s
#
# Root relaxation: objective 9.893248e-01, 14024 iterations, 0.36 seconds (0.74 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.98932    0  735   -0.00000    0.98932      -     -    0s
# H    0     0                       0.6801468    0.98932  45.5%     -    0s
# H    0     0                       0.8355254    0.98932  18.4%     -    0s
# H    0     0                       0.8686278    0.98932  13.9%     -    0s
# H    0     0                       0.9592226    0.98932  3.14%     -    0s
# H    0     0                       0.9805822    0.98932  0.89%     -    0s
# H    0     0                       0.9805826    0.98932  0.89%     -    0s
# H    0     0                       0.9881693    0.98932  0.12%     -    0s
# H    0     0                       0.9881693    0.98932  0.12%     -    0s
# H    0     0                       0.9881701    0.98932  0.12%     -    1s
#      0     0    0.98891    0  589    0.98817    0.98891  0.07%     -    1s
# H    0     0                       0.9881703    0.98891  0.07%     -    1s
#      0     0          -    0         0.98817    0.98817  0.00%     -    1s
#
# Explored 1 nodes (14189 simplex iterations) in 1.36 seconds (1.87 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 0.98817 0.98817 0.98817 ... 0.680147
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.881702590887e-01, best bound 9.881713135820e-01, gap 0.0001%
# 288667970.20610076 12620.122134888936
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x2b552b9e
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [1e-18, 9e-02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [4e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280013 rows and 266541 columns
# Presolve time: 0.09s
# Presolved: 1039 rows, 14510 columns, 28846 nonzeros
# Variable types: 0 continuous, 14510 integer (14510 binary)
# Performing another presolve...
# Presolve removed 5 rows and 5 columns
# Presolve time: 0.06s
#
# Root relaxation: objective 9.928814e-01, 19033 iterations, 0.58 seconds (1.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.99288    0  683   -0.00000    0.99288      -     -    0s
# H    0     0                       0.6640259    0.99288  49.5%     -    0s
# H    0     0                       0.7042012    0.99288  41.0%     -    0s
# H    0     0                       0.8028650    0.99288  23.7%     -    0s
# H    0     0                       0.8029540    0.99288  23.7%     -    0s
# H    0     0                       0.9383576    0.99288  5.81%     -    0s
# H    0     0                       0.9478093    0.99288  4.76%     -    0s
# H    0     0                       0.9680939    0.99288  2.56%     -    0s
# H    0     0                       0.9683414    0.99288  2.53%     -    0s
# H    0     0                       0.9683415    0.99288  2.53%     -    1s
# H    0     0                       0.9683433    0.99288  2.53%     -    1s
# H    0     0                       0.9727380    0.99288  2.07%     -    1s
# H    0     0                       0.9862694    0.99288  0.67%     -    1s
# H    0     0                       0.9885275    0.99288  0.44%     -    1s
# H    0     0                       0.9919751    0.99288  0.09%     -    1s
# H    0     0                       0.9919753    0.99288  0.09%     -    1s
# H    0     0                       0.9919756    0.99198  0.00%     -    1s
#
# Cutting planes:
#   Gomory: 11
#   Zero half: 7
#
# Explored 1 nodes (19033 simplex iterations) in 1.50 seconds (2.01 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 0.991976 0.991975 0.991975 ... 0.968094
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.919756390354e-01, best bound 9.919756390442e-01, gap 0.0000%
# 288667970.20610076 12620.122134888936
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x7b50624b
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [1e-18, 1e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [4e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280013 rows and 266541 columns
# Presolve time: 0.09s
# Presolved: 1039 rows, 14510 columns, 28846 nonzeros
# Variable types: 0 continuous, 14510 integer (14510 binary)
# Performing another presolve...
# Presolve removed 5 rows and 5 columns
# Presolve time: 0.06s
#
# Root relaxation: objective 9.952808e-01, 18789 iterations, 0.61 seconds (1.06 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.99528    0  585   -0.00000    0.99528      -     -    0s
# H    0     0                       0.6559634    0.99528  51.7%     -    0s
# H    0     0                       0.8078738    0.99528  23.2%     -    0s
# H    0     0                       0.8100347    0.99528  22.9%     -    0s
# H    0     0                       0.8100576    0.99528  22.9%     -    0s
# H    0     0                       0.9730696    0.99528  2.28%     -    0s
# H    0     0                       0.9730704    0.99528  2.28%     -    0s
# H    0     0                       0.9748674    0.99528  2.09%     -    0s
# H    0     0                       0.9908890    0.99528  0.44%     -    1s
# H    0     0                       0.9910912    0.99528  0.42%     -    1s
# H    0     0                       0.9911459    0.99528  0.42%     -    1s
# H    0     0                       0.9927420    0.99528  0.26%     -    1s
# H    0     0                       0.9927422    0.99528  0.26%     -    1s
# H    0     0                       0.9931970    0.99528  0.21%     -    1s
# H    0     0                       0.9943201    0.99528  0.10%     -    1s
# H    0     0                       0.9943209    0.99441  0.01%     -    1s
#
# Cutting planes:
#   Gomory: 4
#   Zero half: 10
#
# Explored 1 nodes (18789 simplex iterations) in 1.37 seconds (1.83 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 0.994321 0.99432 0.993197 ... 0.97307
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.943209462209e-01, best bound 9.943209837124e-01, gap 0.0000%
# 288667970.20610076 12620.122134888936
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x355bc0e2
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [1e-18, 1e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [4e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280013 rows and 266541 columns
# Presolve time: 0.10s
# Presolved: 1039 rows, 14510 columns, 28846 nonzeros
# Variable types: 0 continuous, 14510 integer (14510 binary)
# Performing another presolve...
# Presolve removed 5 rows and 5 columns
# Presolve time: 0.06s
#
# Root relaxation: objective 9.987855e-01, 17274 iterations, 0.57 seconds (1.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.99879    0   87   -0.00000    0.99879      -     -    0s
# H    0     0                       0.9073697    0.99879  10.1%     -    0s
# H    0     0                       0.9155350    0.99879  9.09%     -    0s
# H    0     0                       0.9583920    0.99879  4.21%     -    0s
# H    0     0                       0.9583921    0.99879  4.21%     -    0s
# H    0     0                       0.9966983    0.99879  0.21%     -    0s
# H    0     0                       0.9982600    0.99879  0.05%     -    0s
# H    0     0                       0.9982601    0.99879  0.05%     -    0s
#      0     0    0.99851    0   87    0.99826    0.99851  0.02%     -    0s
#
# Explored 1 nodes (17291 simplex iterations) in 1.07 seconds (1.50 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 0.99826 0.99826 0.99826 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.982600675720e-01, best bound 9.982672155329e-01, gap 0.0007%
# 288667970.20610076 12620.122134888936
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 22.5.0 22F66)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281052 rows, 281051 columns and 841646 nonzeros
# Model fingerprint: 0x7ff4e6fd
# Variable types: 0 continuous, 281051 integer (281051 binary)
# Coefficient statistics:
#   Matrix range     [3e-04, 3e+02]
#   Objective range  [1e-18, 1e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [4e+00, 1e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 280015 rows and 266766 columns
# Presolve time: 0.09s
# Presolved: 1037 rows, 14285 columns, 28396 nonzeros
# Variable types: 0 continuous, 14285 integer (14285 binary)
# Performing another presolve...
# Presolve removed 5 rows and 5 columns
# Presolve time: 0.07s
#
# Root relaxation: objective 1.000564e+00, 14239 iterations, 0.53 seconds (0.92 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.00056    0   87   -0.00000    1.00056      -     -    0s
# H    0     0                       0.8862000    1.00056  12.9%     -    0s
# H    0     0                       0.9147743    1.00056  9.38%     -    0s
# H    0     0                       0.9595546    1.00056  4.27%     -    0s
# H    0     0                       0.9971480    1.00056  0.34%     -    0s
# H    0     0                       0.9984442    1.00056  0.21%     -    0s
# H    0     0                       0.9999996    1.00056  0.06%     -    0s
#      0     0    1.00035    0   89    1.00000    1.00035  0.04%     -    1s
#
# Explored 1 nodes (23538 simplex iterations) in 1.21 seconds (1.66 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 8: 1 1 0.998444 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.999996299394e-01, best bound 1.000004516665e+00, gap 0.0005%
# L_drone Analysis: 100%|██████████| 4/4 [04:31<00:00, 67.90s/it]

# %%
# ## 結果の保存
SENSITIVITY_RESULTS_PKL = FINAL_OUTPUT_DIR + 'sensitivity_analysis_results.pkl'
pd.to_pickle(all_results_collection, SENSITIVITY_RESULTS_PKL)
logging.info(f"Sensitivity analysis complete. Results saved to {SENSITIVITY_RESULTS_PKL}")

print("感度分析が完了しました。")
# Out:
# 感度分析が完了しました。

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 all_results_collection
#
# NameError: name 'all_results_collection' is not defined
